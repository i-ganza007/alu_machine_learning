# %%
import matplotlib.pyplot as plt

# %%
y_values =[i for i in range(0,1001,200)]
x_values = [i for i in range(0,11,2)]
act_y = [y**3 for y in x_values]
y_ticks = plt.yticks(y_values)
plt.plot(x_values,act_y,c='red')
plt.show()
